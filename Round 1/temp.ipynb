# %%
import pandas as pd
import numpy as np
import math
import openpyxl

# %%
prices_day_minus2 = pd.read_csv("Round 1\prices_round_1_day_-2.csv", sep=';')
prices_day_minus2
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\cooly\AppData\Local\Temp\ipykernel_13540\3031637594.py:1: SyntaxWarning: invalid escape sequence '\p'
#   prices_day_minus2 = pd.read_csv("Round 1\prices_round_1_day_-2.csv", sep=';')
#        day  timestamp           product  bid_price_1  bid_volume_1  \
# 0       -2          0  RAINFOREST_RESIN         9996             1
# 1       -2          0              KELP         1998            26
# 2       -2          0         SQUID_INK         1998            26
# 3       -2        100         SQUID_INK         1999             5
# 4       -2        100  RAINFOREST_RESIN        10000             5
# ...    ...        ...               ...          ...           ...
# 29995   -2     999800  RAINFOREST_RESIN         9996             1
# 29996   -2     999800              KELP         2026            26
# 29997   -2     999900  RAINFOREST_RESIN         9996             2
# ...

# %%
prices_day_minus2.to_excel("prices_day_minus2.xlsx", sheet_name='Sheet1', index=False)
