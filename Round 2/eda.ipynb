# %%
import pandas as pd
import numpy as np
import math 
import statistics
import matplotlib.pyplot as plt
import seaborn as sns

# %%
prices = pd.read_excel('data/prices.xlsx')
prices
# Out:
#         day  timestamp         product  bid_price_1  bid_volume_1  \
# 0        -1          0      CROISSANTS         4304           112
# 1        -1          0            JAMS         6670            66
# 2        -1          0       SQUID_INK         2005             1
# 3        -1          0  PICNIC_BASKET1        59284            20
# 4        -1          0  PICNIC_BASKET2        30606            20
# ...     ...        ...             ...          ...           ...
# 239995    1     999900       SQUID_INK         1799            20
# 239996    1     999900         DJEMBES        13419            70
# 239997    1     999900            KELP         2043            20
# 239998    1     999900      CROISSANTS         4266           119
# 239999    1     999900            JAMS         6519           204
#
#         bid_price_2  bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  \
# 0               NaN           NaN          NaN           NaN         4305
# 1            6669.0         137.0          NaN           NaN         6671
# 2            2002.0          31.0          NaN           NaN         2006
# 3           59283.0          18.0          NaN           NaN        59294
# 4           30605.0          18.0          NaN           NaN        30612
# ...             ...           ...          ...           ...          ...
# 239995          NaN           NaN          NaN           NaN         1802
# 239996          NaN           NaN          NaN           NaN        13420
# 239997          NaN           NaN          NaN           NaN         2047
# 239998          NaN           NaN          NaN           NaN         4267
# 239999          NaN           NaN          NaN           NaN         6521
#
#         ask_volume_1  ask_price_2  ask_volume_2  ask_price_3  ask_volume_3  \
# 0                112          NaN           NaN          NaN           NaN
# 1                 66       6672.0         137.0          NaN           NaN
# 2                 31          NaN           NaN          NaN           NaN
# 3                  2      59295.0          36.0          NaN           NaN
# 4                 20      30613.0          18.0          NaN           NaN
# ...              ...          ...           ...          ...           ...
# 239995            20          NaN           NaN          NaN           NaN
# 239996            70          NaN           NaN          NaN           NaN
# 239997            20          NaN           NaN          NaN           NaN
# 239998            44       4268.0          75.0          NaN           NaN
# 239999           204          NaN           NaN          NaN           NaN
#
#         mid_price  profit_and_loss  global_time
# 0          4304.5                0     -1000000
# 1          6670.5                0     -1000000
# 2          2005.5                0     -1000000
# 3         59289.0                0     -1000000
# 4         30609.0                0     -1000000
# ...           ...              ...          ...
# 239995     1800.5                0      1999900
# 239996    13419.5                0      1999900
# 239997     2045.0                0      1999900
# 239998     4266.5                0      1999900
# 239999     6520.0                0      1999900
#
# [240000 rows x 18 columns]

# %%
unique_products = prices['product'].unique()

for product in unique_products:
    product_df = prices[prices['product'] == product]
    
    plt.figure(figsize=(16, 8))
    plt.plot(product_df['global_time'], product_df['mid_price'], marker='o')
    plt.title(f"Mid Price Time Series for Product: {product}")
    plt.xlabel("Global Time (Combined day & timestamp)")
    plt.ylabel("Mid Price")
    plt.grid(True)
    plt.tight_layout()
    plt.show()
